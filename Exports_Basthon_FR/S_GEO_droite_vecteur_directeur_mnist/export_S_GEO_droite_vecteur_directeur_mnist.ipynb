# %% [markdown]
# ??? danger Vous êtes professeur ? Cliquez ici pour obtenir les ressources associées à ce notebook
#
# Ce notebook est conçu pour être utilisé avec des ressources (diaporama, fiche d'exercice et vidéo).
#
# Retrouvez-les dans l'espace professeur du site [mathadata.fr](https://mathadata.fr/fr).
#
# Pour tout retour, coquille, demande d'aide, critique, ou félicitations, contactez-nous sur [question-notebook@mathadata.fr](mailto:question-notebook@mathadata.fr).
#
# Notebook exporté le 21-12-2025 11:11:38
# <!-- depuis le commit 5455ffc -->
#
# ???

# %% [markdown]
# # MathAData - Géométrie dans le plan, droites

# %% [markdown]
# !!! abstract But du TP  : Classification des images de 2 et de 7
# Dans ce Notebook, nous allons construire un algorithme qui prédit si un 2 ou un 7 est écrit sur une image.
# ![2_7.png](attachment:2_7.png)
# !!!

# %% [markdown]
# !!! tip Exécuter une cellule
# Pour commencer, **clique dans la cellule** de code ci-dessous puis appuie dans la barre d'outils sur le bouton **Exécuter**
#  <span style="display: inline-block; margin: auto 1rem; vertical-align: middle">![execute_barre_outil_inline.png](attachment:execute_barre_outil_inline.png)</span>
# ou sur les touches <span style="display: inline-block; margin: auto 1rem; vertical-align: middle">![majentr.png](attachment:majentr.png)</span>.
# Lorsque le code aura été exécuté, une étoile apparaîtra le temps du chargement puis un nombre entre les crochets sur la gauche : <span style="display: inline-block; margin: auto 1rem; vertical-align: middle">![cellule_executee.png](attachment:cellule_executee.png)</span>
# !!!
#
#
# ??? warning SOS : Rien ne se passe ? Clique ici
#
# ### Rien ne se passe quand tu exécutes une cellule ?
#
# **Cas 1 : La cellule n'a pas été exécutée.**
# Tu vois ceci : <span style="display: inline-block; margin: auto 1rem; vertical-align: middle">![aide_nonclic.jpg](attachment:aide_nonclic.jpg)</span>
#
# **Solution :** Clique dans la cellule (sur le mot `from` par exemple) puis appuie sur le bouton <span style="display: inline-block; margin: auto 1rem; vertical-align: middle">![executer.png](attachment:executer.png)</span>
#
# ---
#
# **Cas 2 : La cellule est en cours d'exécution.**
# Tu vois ceci : <span style="display: inline-block; margin: auto 1rem; vertical-align: middle">![aide_patience.jpg](attachment:aide_patience.jpg)</span>
#
# **Solution :** La base de données se charge. Patiente jusqu'à une minute.
#
# ---
#
# **Cas 3 : Rien ne fonctionne malgré les solutions ci-dessus ?**
#
# **Solution :** Relance le notebook depuis le début :
#
# 1. Clique sur le bouton **deux petites flèches** <span style="display: inline-block; margin: auto 1rem; vertical-align: middle">![rerun_button.png](attachment:rerun_button.png)</span> dans la barre d'outils en haut du notebook
#
#
# 2. Clique ensuite sur le bouton rouge **"Relancer et exécuter toutes les cellules"**
# ![rerun_instruction_fr.png](attachment:rerun_instruction_fr.png)
#
# ???

# %%
# Clique dans cette cellule de code puis appuie sur le bouton Exécuter dans la barre d'outils
from utilitaires_mnist import *

# %% [markdown]
# <div id="debut-etape-bdd" style="height: 1px; visibility: hidden;"></div>

# %% [markdown]
# !!! tip Base de données
# Nous avons environ 6 000 images.
# **Exécute la cellule suivante** pour afficher la base de données. Tu peux cliquer sur une ligne pour afficher l'image correspondante et te déplacer avec les flèches haut et bas du clavier.
# !!!

# %%
# Clique dans cette cellule de code puis appuie sur le bouton Exécuter
from utilitaires_S_GEO_droite_vecteur_directeur import *
affichage_banque()
validation_execution()

# %% [markdown]
# !!! question 1) Parmi les 10 premières images, combien d'images de 7 y a-t-il  ?
#  **Remplace les `...`** dans la cellule suivante par ta réponse **puis exécute**.
# !!!

# %%
nombre_7 = ...

# NE PAS TOUCHER APRES CETTE LIGNE
validation_question_nombre()

# %% [markdown]
# <div id="debut-etape-depart" style="height: 1px; visibility: hidden;"></div>

# %% [markdown]
# ## A. Algorithme de départ

# %% [markdown]
# !!! tip Fonctionnement d'un algorithme
# Un algorithme reçoit une donnée, effectue des opérations, et donne une réponse.
# ![algo_blackbox.png](attachment:algo_blackbox.png)
# Plusieurs stratégies sont possibles pour déterminer la réponse.
# !!!
# !!! abstract Algorithme fainéant : Répondre toujours 2.
# LucIA ne veut pas se fatiguer et propose un algorithme très simple **qui répond toujours 2**.
# Cela veut dire que peu importe l'image, l'algorithme ne "réfléchit" pas et dit juste : "Je pense que c'est une image de 2"
#
# Voici le code de cet algorithme très simple ci-dessous. **Exécute la cellule pour passer à la suite**.
# !!!

# %%
import utilitaires_common

def algorithme(d):
    return 2

validation_execution_algo_fixe()

# %% [markdown]
# !!! tip Teste l'algorithme fainéant
# **Exécute la cellule suivante** pour tester l'algorithme fainéant
# !!!

# %%
test_algorithme_faineant()
validation_execution_test_algorithme_faineant()

# %% [markdown]
# !!! question 2) Que répond l'algorithme fainéant pour ces trois images ?
# ![frise_trois_images_scale.png](attachment:frise_trois_images_scale.png)
# **Remplace les `...`** dans la cellule suivante par ta réponse  **puis exécute**.
# !!!

# %%
Reponse_Donnee_A = ...
Reponse_Donnee_B = ...
Reponse_Donnee_C = ...

# NE PAS TOUCHER APRES CETTE LIGNE
validation_question_faineant()

# %% [markdown]
# ### Le taux d'erreur

# %% [markdown]
# !!! info Le pourcentage d'erreur : un moyen d'évaluer ton algorithme
# Voici la formule donnant la proportion d'erreur :
# $$\text{erreur} = \frac{\text{Nombre d'images mal classées}} {\text{Nombre total d'images}}$$
# Plus la proportion d'erreur de ton algorithme est basse, meilleure est ta solution.
# !!!

# %%
affichage_banque(showPredictions=True)
validation_execution_calcul_score()

# %% [markdown]
# !!! question 3) Sur les 10 premières images, quel est le pourcentage d'erreur de l'algorithme ?
# Calcule le pourcentage d'erreur de l'algorithme sur les 10 premières images.
# **Remplace les `...`** dans la cellule suivante par ta réponse (uniquement le nombre sans le %) **puis exécute**.
# !!!
#
# ??? tip Aide calcul : exprimer une proportion en pourcentage
# Une proportion peut s'écrire en pourcentage en multipliant par $100\%$.
# Par exemple, si l'algorithme fait 4 erreurs sur 20 images : $$\text{erreur} = \frac{4}{20}=0,2=0,2\times100\% = 20\%.$$
# ???

# %%
erreur_10 = ...

# NE PAS TOUCHER APRES CETTE LIGNE
validation_question_score_fixe()

# %% [markdown]
# !!! tip Taux d'erreur sur toutes les images
# **Exécute la cellule suivante** pour calculer le pourcentage d'erreur sur l'ensemble des 6 073 images.
# !!!

# %%
calculer_score_etape_1(animation=False, banque=False)

# %% [markdown]
# <div id="debut-etape-data" style="height: 1px; visibility: hidden;"></div>

# %% [markdown]
# ## B. La donnée pour l'ordinateur : image numérique

# %% [markdown]
# !!! abstract Qu'est-ce qu'une image ?
# Pour diminuer notre erreur, notre algorithme doit "regarder" l'image. On doit comprendre ce qu'est l'image pour l'ordinateur.
# !!!
# !!! tip Calcul sur l'image
# Pour l'ordinateur, une image est un tableau de nombres. Chaque nombre correspond à un pixel de l'image. Chaque pixel vaut entre 0 et 255, 0 pour noir et 255 pour blanc.
# ![pixels_scale.png](attachment:pixels_scale.png)
# **Exécute la cellule suivante pour voir un exemple.**
# !!!

# %%
question_pixel()

# %% [markdown]
# !!! tip Visualisation des pixels de l'image
# **Exécute la cellule suivante** pour voir une image complète avec les valeurs de ses pixels.
# !!!

# %%
affichage_image_et_pixels()
validation_execution_affichage()

# %% [markdown]
# <div id="debut-etape-carac" style="height: 1px; visibility: hidden;"></div>

# %% [markdown]
# ## C. Caractéristiques

# %% [markdown]
# ### Calcul des caractéristiques

# %% [markdown]
# !!! tip Résumer l'image avec 2 nombres caractéristiques
# Pour représenter une image par un point du plan, l'algorithme calcule deux nombres $x$ et $y$ à partir des pixels de l'image.
# Commençons par deux nombres simples : la moyenne sur la moitié haute de l'image et la moyenne sur la moitié basse.
# ![image_2_caracs_scale.png](attachment:image_2_caracs_scale.png)
# !!!

# %% [markdown]
# !!! question 4) Calcule les caractéristiques de ces deux images
# Calcule les deux caractéristiques du 2 : $( \; \text{moyenne en haut} \; ; \; \text{moyenne en bas} \; )$.
#
# Pour 7, les deux caractéristiques sont :
#
# $x_7 = \frac{5 \times 180}{9} = 100 ; \quad y_7 = \frac{3 \times 180}{9} = 60.$ <span style="display: inline-block; margin: auto 1rem; vertical-align: middle">![mnist_deux_mini_images.png](attachment:mnist_deux_mini_images.png)</span>
#
# **Remplace les `...`** dans la cellule suivante par les valeurs des deux caractéristiques, **puis exécute**.
# !!!

# %% [markdown]
# ??? example Pour le calcul mental : $180=20 \times 9 $ et $20=2 \times 10$
# ???

# %%
x_2 = ...
y_2 = ...

# NE PAS TOUCHER APRES CETTE LIGNE
validation_carac()

# %% [markdown]
# ### Visualisation dans le plan

# %% [markdown]
# !!! info Visualisation dans le plan
# Nous avons maintenant deux valeurs $(x ; y)$ associées à chaque image. Nous pouvons placer les images dans un plan en utilisant $x$ et $y$ comme coordonnées.
#
# **Exécute la cellule suivante** pour poursuivre.
# !!!

# %%
placer_2_points()
validation_execution_placer_2_points()

# %% [markdown]
# !!! question 5) Place les points A et B dans le plan
# Voici le couple de caractéristiques  $(x ; y)$ pour deux petites images A et B ci-dessus. Clique sur le graphique au bon endroit pour placer les points $A$ et $B$ avec leurs coordonnées.
#
# **Exécute la cellule suivante** après avoir observé les points.
# !!!

# %%
validation_placer_2_points()

# %% [markdown]
# !!! info Nuages de points
# Nous allons maintenant étudier la répartition dans le plan des images de 2 et des images de 7. Plus notre caractéristique est discriminante, plus on peut observer 2 nuages (groupes) de points distincts.
#
# **Exécute la cellule suivante** pour afficher les points correspondant aux 200 premières images de l'ensemble d'entraînement.
# !!!

# %%
tracer_200_points()
validation_execution_200_points()

# %% [markdown]
# !!! question 6) Quel nuage de points correspond à quelle classe ?
# À ton avis, les points de couleur bleue correspondent aux images de 2 ou aux images de 7 ?
#
# **Remplace les `...`** dans la cellule suivante avec 2 ou 7 dans le bon ordre **puis exécute**.
# !!!

# %%
classe_points_bleus = ...
classe_points_oranges = ...

# NE PAS TOUCHER APRES CETTE LIGNE
validation_question_couleur()

# %% [markdown]
# <div id="debut-etape-classif" style="height: 1px; visibility: hidden;"></div>

# %% [markdown]
# ### Classification

# %% [markdown]
# !!! info Classification
# La classification est la dernière étape de l'algorithme. Il faut trouver un moyen de donner une réponse 2 ou 7 à partir des caractéristiques $x, y$.  En deux dimensions, on peut utiliser une droite pour séparer les points en deux groupes.
# ![classification_2_droite.png](attachment:classification_2_droite.png)
# !!!

# %% [markdown]
# !!! info Découpage du plan par une droite
#
# **Exécute la cellule suivante** pour voir le découpage par une droite avec les points pour 20 images.
#
# !!!

# %%
tracer_20_points_droite()
validation_execution_20_points()

# %% [markdown]
# !!! question 7) Quel est le pourcentage d'erreur sur ce schéma pour ces 20 images ?
# Calcule le pourcentage d'erreur pour ces 20 images et cette droite. Les points au-dessus de la droite sont classés comme 2 par l'algorithme et ceux en-dessous comme 7.
# **Remplace les `...`** dans la cellule suivante par ta réponse (uniquement le nombre sans le %) **puis exécute**.
# !!!

# %%
erreur_20 = ...

# NE PAS TOUCHER APRES CETTE LIGNE
validation_question_score_droite_20()

# %% [markdown]
# !!! info Comment décrire la droite de séparation dans l'algorithme ?
#
# Tu vas manipuler :
#
# - un vecteur $\overrightarrow{u}$ qui donne la direction de la droite de séparation
# - un point de passage $A$ de la droite
#
# Déplace le curseur du réel $\lambda$ (prononcé lambda) pour déplacer la position du point $M$ tel que :
# $$\overrightarrow{AM}= \lambda \overrightarrow{u}$$
#
# !!!

# %%
lalambdada_exercice()

validation_execution_lalambdada_exercice()

# %% [markdown]
# !!! question 8) Détermine la valeur de $\lambda_P$ permettant d'atteindre le point $P(80;60)$.
# Remplace les ... dans la cellule ci-dessous par la valeur de $\lambda_P$ adaptée.
# !!!

# %%
# Valeur de lambda permettant d'atteindre P
lambda_P = ... 

# NE PAS TOUCHER APRES CETTE LIGNE
validation_exercice_lambda_P()

# %% [markdown]
# !!! tip A toi
# Tu vas maintenant chercher la meilleure droite pour résoudre le challenge en choisissant un vecteur directeur $\overrightarrow{u}$ et un point de passage $A$ de la droite.
#
# **Exécute la cellule suivante** pour afficher les points pour toutes les images de la base de données.
# !!!

# %%
tracer_points_droite_vecteur_directeur()
validation_execution_tracer_points_droite_vecteur()

# %% [markdown]
# !!! question 9) Trouve une droite permettant d'obtenir moins de 10% d'erreur
# Ajuste les paramètres du vecteur $\vec u \begin{pmatrix}x_u\\ y_u \end{pmatrix}$ et du point $A(x_A;y_A)$ pour trouver une bonne droite séparatrice. Le pourcentage d'erreur est la proportion de points d'un groupe qui sont du mauvais côté de la droite.
#
#
# Quand tu auras trouvé une bonne droite, **exécute la cellule suivante** pour passer à la suite.
# !!!

# %%
calculer_score_droite()

# %% [markdown]
# !!! question 10) Quelles sont les coordonnées de $\vec u$ que tu as choisi ?
# Lis sur la figure ci-dessus les coordonnés de $\vec u \begin{pmatrix}x_u\\ y_u \end{pmatrix}$.
#
# **Remplace $x_u$ et $y_u$ dans la cellule suivante puis exécute-la.**
# !!!

# %%
x_u = ...
y_u = ...


# NE PAS MODIFIER LA LIGNE EN-DESSOUS
validation_question_lecture_u()

# %% [markdown]
# !!! question 11) Le vecteur directeur est-il unique ?
# Pour répondre à cette question, **exécute la cellule ci-dessous**.
# !!!

# %%
afficher_plusieurs_vecteurs()
qcm_vecteurs_directeurs()

# %% [markdown]
# !!! info Un vecteur $\overrightarrow{u}$ et un point $A$ permettent de décrire une droite.
# Nous allons découvrir comment obtenir l'équation d'une droite.
#
# Si un point $M$ est sur la droite définie par le vecteur $\overrightarrow{u}$ et un point $A$
# alors les vecteurs $\overrightarrow{AM}$ et $\overrightarrow{u}$ sont colinéaires.
#
# **Éxécute** la cellulle suivante.
# !!!

# %%
qcm_vecteur_colineaire()

# %% [markdown]
# !!! info Exécute la cellule suivante pour manipuler le déterminant $det (\overrightarrow{AM} ; \vec u )$
# Déplace le point M et observe comment le déterminant change.
# !!!

# %%
determinant_decouverte_exercice()
validation_execution_determinant_exercice()

# %% [markdown]
# !!! question 12) Détermine un point $M$ tel que  $det (\overrightarrow{AM} ; \vec u )=0$.
# Remplace les ... par la valeur de $x_M$ et $y_M$.
# !!!

# %%
M = ( ... , ... )

# NE PAS MODIFIER LA LIGNE EN-DESSOUS
validation_question_point_determinant_zero_M()

# %%
# EXECUTE CETTE CELLULE
qcm_determinant_nul()

# %% [markdown]
# !!! info Il est possible de définir une droite par une équation.
# On peut obtenir une équation **cartésienne** de la forme $ax+by+c=0$  :
# Prenons un point <span style="display: inline-block; margin: auto 1rem; vertical-align: middle">![detpointM.png](attachment:detpointM.png)</span> sur la droite définie par le point $A( 20 ; 10 )$ et le vecteur directeur <span style="display: inline-block; margin: auto 1rem; vertical-align: middle">![detvecteurdiru.png](attachment:detvecteurdiru.png)</span>.
# On obtient l'équation suivante (voir le détail du calcul pour les curieuses et curieux) :
# <span style="display: inline-block; margin: auto 1rem; vertical-align: middle">![detequation.png](attachment:detequation.png)</span>
#
# !!!
#
# ??? example En cliquant ici tu verras le détail du calcul. Attention il peut faire peur.
# ![detmonstre.png](attachment:detmonstre.png)
#
# ???
#
# !!! question 13) Si on change les coordonnées du vecteur $\overrightarrow{u}\begin{pmatrix} 20 \\ 30 \end{pmatrix}$ par $\overrightarrow{u}\begin{pmatrix} 10 \\ 5 \end{pmatrix}$ dans le calcul que vaut $a$ à la fin ?
#
# Si cette question est trop difficile répond `chat` pour passer.
# !!!

# %%
a = ...

# Ne pas toucher à la ligne en dessous
validation_question_cartesienne_determinant()

# %% [markdown]
# !!! info Equation cartésienne et vecteur directeur
#
# Découvrons les liens entre la droite d'équation ${\color{red} a}x~+~{\color{green} b}y~+~{\color{blue} c}~=~0$ et le vecteur $\begin{pmatrix} -{\color{green} b} \\ {\color{red} a} \end{pmatrix}$.
#
# !!!

# %%
tracer_points_droite_a_b_c()

validation_execution_tracer_points_droite_directeur()

# %% [markdown]
# !!! question 14) Déterminer un vecteur directeur.
#
# Donne un vecteur directeur $\overrightarrow{u}$ possible pour l'équation de droite $3x-4y+1=0$.
#
# !!!
#
# ??? warning Aide
#
# La droite d'équation ${\color{red} a}x~+~{\color{green} b}y~+~{\color{blue} c}~=~0$ admet pour vecteur directeur le vecteur $\begin{pmatrix} -{\color{green} b} \\ {\color{red} a} \end{pmatrix}$.
#
# ???

# %%
u = ( ... , ... )

# NE PAS TOUCHER APRES CETTE LIGNE
validation_question_vecteur_directeur_possible()

# %% [markdown]
# #### Droite et équation cartésienne

# %% [markdown]
# !!! info Equation cartésienne
#
# Découvrons l'influence des paramètres $a$, $b$ et $c$ de l'équation ${\color{red} a}x~+~{\color{green} b}y~+~{\color{blue} c}~=~0$.
#
#
# **Exécute la cellule suivante**, jouez avec les paramètres${\color{red} a}$, ${\color{green} b}$ et ${\color{blue} c}$, puis réponds aux question.
#
# !!!

# %%
tracer_points_droite_c()

validation_execution_tracer_points_droite_c()

# %%
qcm_abc_cartesienne_c()

# %%
tracer_points_droite_a_b()

validation_execution_tracer_points_droite_a_b()

# %%
qcm_abc_cartesienne_a()

# %%
qcm_abc_cartesienne_b()

# %% [markdown]
# #### Détail du calcul de l'erreur

# %% [markdown]
# <div id="debut-etape-custom" style="height: 1px; visibility: hidden;"></div>

# %% [markdown]
# ## D. Essayons de trouver 2 meilleures caractéristiques !

# %% [markdown]
# !!! info Comment choisir des bonnes caractéristiques ?
# Avant, on utilisait comme caractéristiques les moyennes des zones du haut et du bas de l’image. Maintenant, on va faire pareil, mais avec d’autres zones.
#
# On choisira deux zones identiques pour toutes les images. Pour qu’elles donnent de meilleures caractéristiques, elles doivent être bien placées pour représenter la forme de nos deux chiffres.
#
# ![mnist_choix_zones_mini_images.png](attachment:mnist_choix_zones_mini_images.png)
#
# !!!
#
# !!! question 15) Quelles zones choisir ?
# Voici deux choix de zones pour différencier un 2 d’un 7. En observant les zones entourées, lequel permet le mieux de distinguer ces deux chiffres ?
#
# Rappelle-toi : on calcule la moyenne des pixels de chaque zone pour obtenir un point par image et on cherche des nuages de points bien séparés.
#
# **Executez la cellule suivante** pour faire ton choix dans le QCM.
# !!!

# %%
qcm_choix_caracteristiques()

# %% [markdown]
# !!! question 16) Exemple de mauvaises caractéristiques
# Dans la suite, on traite le premier choix des zones (images de gauche).
#
# **Executez la cellule suivante** pour afficher les régions et place sur le graphique les points correspondant aux images.
# !!!

# %%
mauvaises_caracteristiques()

validation_execution_mauvaises_caracteristiques()

# %%
validation_moyenne_carac_mauvaise()

# %% [markdown]
# !!! question 17) Exemple de meilleures caractéristiques
# Maintenant, on traite le deuxième choix des zones (à droite).
#
# **Executez la cellule suivante** pour afficher les nouvelles régions et place sur le graphique les points correspondant aux nouvelles caractéristiques.
# !!!

# %%
meilleures_caracteristiques()

validation_execution_meilleures_caracteristiques()

# %%
validation_moyenne_carac_meilleure()

# %% [markdown]
# ### Trouve tes propres caractéristiques

# %% [markdown]
# !!! question 18) Changer les zones choisies pour définir tes propres caractéristiques
# **Exécute la cellule suivante** puis sélectionne deux zones sur l'image. Les caractéristiques $x$ et $y$ seront la moyenne des pixels dans chacune des zones.
# Clique sur le bouton zone x ou zone y pour choisir la zone à sélectionner, puis clique sur l'image et laissez appuyé jusqu'à avoir selectionné la zone souhaitée.
# !!!

# %%
afficher_customisation()

validation_execution_afficher_customisation()

# %% [markdown]
# !!! question 19) Trouve la meilleure droite.
# Ajuste les paramètres de la droite pour trouver une bonne droite séparatrice. Le pourcentage d'erreur est la proportion de points d'un groupe qui sont du mauvais côté de la droite.
#
# **Exécute la cellule suivante** pour passer à la suite quand tu auras moins de 8% d'erreur. Il faut pour ça trouver deux bonnes zones et ajuster la droite.
# !!!

# %% [markdown]
# !!! warning SOS <details> <summary>Rien ne se passe ? Clique ici  </summary>
#  Avec la souris sélectionne une zone dans une des images :
# -clique sur zone 2
# -sélectionne une zone
# -clique sur zone 1
# -sélectionne une zone
#
#  L'enjeu est de trouver des zones permettant de différencier les 2 et les 7.  </details>
# !!!

# %%
calculer_score_custom_droite()

# %% [markdown]
# !!! abstract Fin du Notebook
# Dans ce TP, tu as :
#
# - Utilisé deux caractéristiques pour chaque image
# - Placé les images dans un plan en utilisant ces deux valeurs comme coordonnées
# - Utilisé une droite pour séparer les points en deux groupes
# - Optimisé les paramètres de la droite pour minimiser ton erreur
#
# Continue à chercher des bonnes zones pour diminuer ton pourcentage d'erreur. Tu peux faire jusqu'à moins de 3% d'erreur !
# !!!
