# %% [markdown]
# ??? danger Vous êtes professeur ? Cliquez ici pour obtenir les ressources associées à ce notebook
#
# Ce notebook est conçu pour être utilisé avec des ressources (diaporama, fiche d'exercice et vidéo).
#
# Retrouvez-les dans l'espace professeur du site [mathadata.fr](https://mathadata.fr/fr).
#
# Pour tout retour, coquille, demande d'aide, critique, ou félicitations, contactez-nous sur [question-notebook@mathadata.fr](mailto:question-notebook@mathadata.fr).
#
# Notebook exporté le 02-01-2026 13:18:13
# <!-- depuis le commit c1b00ab -->
#
# ???

# %% [markdown]
# # MathAData - Module Statistiques - 1

# %% [markdown]
# !!! abstract But du TP  : Alerter en cas de risque pour la santé du foetus durant l'accouchement
# Dans ce Notebook, nous allons construire un algorithme qui aide les soignants lors de l'accouchement. Pour la santé du nouveau-né, on doit déterminer si l'état d'un foetus est **normal** ou **alarmant**. Pour cela on analyse le rythme cardiaque du foetus.
# !!!

# %% [markdown]
# !!! tip Exécuter une cellule
# Pour commencer, **clique dans la cellule** de code ci-dessous puis appuie dans la barre d'outils sur le bouton **Exécuter**
#  <span style="display: inline-block; margin: auto 1rem; vertical-align: middle">![execute_barre_outil_inline.png](attachment:execute_barre_outil_inline.png)</span>
# ou sur les touches <span style="display: inline-block; margin: auto 1rem; vertical-align: middle">![majentr.png](attachment:majentr.png)</span>.
# Lorsque le code aura été exécuté, une étoile apparaîtra le temps du chargement puis un nombre entre les crochets sur la gauche : <span style="display: inline-block; margin: auto 1rem; vertical-align: middle">![cellule_executee.png](attachment:cellule_executee.png)</span>
# !!!
#
#
# ??? warning SOS : Rien ne se passe ? Clique ici
#
# ### Rien ne se passe quand tu exécutes une cellule ?
#
# **Cas 1 : La cellule n'a pas été exécutée.**
# Tu vois ceci : <span style="display: inline-block; margin: auto 1rem; vertical-align: middle">![aide_nonclic.jpg](attachment:aide_nonclic.jpg)</span>
#
# **Solution :** Clique dans la cellule (sur le mot `from` par exemple) puis appuie sur le bouton <span style="display: inline-block; margin: auto 1rem; vertical-align: middle">![executer.png](attachment:executer.png)</span>
#
# ---
#
# **Cas 2 : La cellule est en cours d'exécution.**
# Tu vois ceci : <span style="display: inline-block; margin: auto 1rem; vertical-align: middle">![aide_patience.jpg](attachment:aide_patience.jpg)</span>
#
# **Solution :** La base de données se charge. Patiente jusqu'à une minute.
#
# ---
#
# **Cas 3 : Rien ne fonctionne malgré les solutions ci-dessus ?**
#
# **Solution :** Relance le notebook depuis le début :
#
# 1. Clique sur le bouton **deux petites flèches** <span style="display: inline-block; margin: auto 1rem; vertical-align: middle">![rerun_button.png](attachment:rerun_button.png)</span> dans la barre d'outils en haut du notebook
#
#
# 2. Clique ensuite sur le bouton rouge **"Relancer et exécuter toutes les cellules"**
# ![rerun_instruction_fr.png](attachment:rerun_instruction_fr.png)
#
# ???

# %%
# Clique dans cette cellule de code puis appuie sur le bouton Exécuter dans la barre d'outils 

from utilitaires_foetus import *

# %% [markdown]
# ## A. Rythme cardiaque du foetus

# %% [markdown]
# !!! abstract Qu'est-ce qu'un **enregistrement du rythme cardiaque** ?
# Un **enregistrement du rythme cardiaque** donne la fréquence cardiaque en fonction du temps, exprimée en nombre de battements de coeur par minute.
# ![animation_placeholder.png](attachment:animation_placeholder.png)
# Sur l'image ci-dessus, chaque point représente la fréquence cardiaque à un instant donné.
# !!!

# %%
animation_battement()

validation_animation_battement()

# %% [markdown]
# !!! tip Base de données
# Nous avons environ 500 enregistrements cardiaques.
# **Exécute la cellule suivante** pour afficher la base de données. Tu peux cliquer sur une ligne pour afficher l'enregistrement cardiaque correspondant et te déplacer avec les flèches haut et bas du clavier.
# !!!

# %%
# Clique dans cette cellule de code puis appuie sur le bouton Exécuter
from utilitaires_S_STATS_moyenne_histogramme import *
affichage_banque()
validation_execution()

# %% [markdown]
# !!! question 1) Parmi les 10 premiers enregistrements cardiaques, combien de cas alarmants y a-t-il  ?
#  **Remplace les `...`** dans la cellule suivante par ta réponse **puis exécute**.
# !!!

# %%
nombre_ALARMANT = ...

# NE PAS TOUCHER APRES CETTE LIGNE
validation_question_nombre()

# %% [markdown]
# ## B. Algorithme de départ

# %% [markdown]
# !!! tip Fonctionnement d'un algorithme
# Un algorithme reçoit une donnée, effectue des opérations, et donne une réponse.
# ![algo_blackbox.png](attachment:algo_blackbox.png)
# Plusieurs stratégies sont possibles pour déterminer la réponse.
# !!!
# !!! abstract Algorithme fainéant : Répondre toujours Normal.
# LucIA ne veut pas se fatiguer et propose un algorithme très simple **qui répond toujours Normal**.
# Cela veut dire que peu importe l'enregistrement cardiaque, l'algorithme ne "réfléchit" pas et dit juste : "Je pense que c'est un cas normal"
#
# Voici le code de cet algorithme très simple ci-dessous. **Exécute la cellule pour passer à la suite**.
# !!!

# %%
import utilitaires_common

def algorithme(d):
    return "Normal"

validation_execution_algo_fixe()

# %% [markdown]
# !!! tip Teste l'algorithme fainéant
# **Exécute la cellule suivante** pour tester l'algorithme fainéant
# !!!

# %%
test_algorithme_faineant()
validation_execution_test_algorithme_faineant()

# %% [markdown]
# !!! question 2) Que répond l'algorithme fainéant pour ces trois enregistrements cardiaques ?
# ![frise_trois_images_scale.png](attachment:frise_trois_images_scale.png)
# **Remplace les `...`** dans la cellule suivante par ta réponse  **puis exécute**.
# !!!

# %%
Reponse_Donnee_A = ...
Reponse_Donnee_B = ...
Reponse_Donnee_C = ...

# NE PAS TOUCHER APRES CETTE LIGNE
validation_question_faineant()

# %% [markdown]
# ### Le taux d'erreur

# %% [markdown]
# !!! info Le pourcentage d'erreur : un moyen d'évaluer ton algorithme
# Voici la formule donnant la proportion d'erreur :
# $$\text{erreur} = \frac{\text{Nombre d'enregistrements cardiaques mal classés}} {\text{Nombre total d'enregistrements cardiaques}}$$
# Plus la proportion d'erreur de ton algorithme est basse, meilleure est ta solution.
# !!!

# %%
affichage_banque(showPredictions=True)
validation_execution_calcul_score()

# %% [markdown]
# !!! question 3) Sur les 10 premiers enregistrements cardiaques, quel est le pourcentage d'erreur de l'algorithme ?
# Calcule le pourcentage d'erreur de l'algorithme sur les 10 premiers enregistrements.
# **Remplace les `...`** dans la cellule suivante par ta réponse (uniquement le nombre sans le %) **puis exécute**.
# !!!
#
# ??? tip Aide calcul : exprimer une proportion en pourcentage
# Une proportion peut s'écrire en pourcentage en multipliant par $100\%$.
# Par exemple, si l'algorithme fait 4 erreurs sur 20 enregistrements cardiaques : $$\text{erreur} = \frac{4}{20}=0,2=0,2\times100\% = 20\%.$$
# ???

# %%
erreur_10 = ...

# NE PAS TOUCHER APRES CETTE LIGNE
validation_question_score_fixe()

# %% [markdown]
# !!! tip Taux d'erreur sur tous les enregistrements cardiaques
# **Exécute la cellule suivante** pour calculer le pourcentage d'erreur sur l'ensemble des 453 enregistrements.
# !!!

# %%
calculer_score_etape_1(animation=False, banque=False)

# %% [markdown]
# ## C. Les données numériques

# %% [markdown]
# !!! info Un enregistrement cardiaque pour un ordinateur ?
# Pour l'ordinateur, l'enregistrement cardiaque est une série de nombres. Nous avons 1 mesure par seconde c'est-à-dire que la $n$ième valeur correspond à la fréquence cardiaque  après $n$ secondes.
# Exécute la cellule suivante pour afficher le tableau des valeurs de l'enregistrement ci-dessus.
# !!!

# %%
affichage_tableau(d)
affichage_html(d)
validation_execution_affichage_tableau()

# %% [markdown]
# !!! question 4) Quelle est la fréquence cardiaque après 3 secondes ?
# Regarde le tableau des valeurs de la fréquence cardiaque et indique dans la cellule suivante la valeur après 3 secondes.
# !!!

# %%
frequence = ...

# NE PAS TOUCHER APRES CETTE LIGNE
validation_question_frequence()

# %% [markdown]
# !!! question 5) Quelles sont les différences entre un cas Normal et un cas ALARMANT ?
# En regardant bien des enregistrements du rythme cardiaque, on voit que les foetus ayant un problème ont plus souvent des baisses de fréquence cardiaque ou des changements rapides.
# Exécute la cellule suivante puis dis pour chaque enregistrement cardiaque quel cas est Normal et lequel est ALARMANT.
# !!!

# %%
exercice_classification()
validation_execution_exercice_classification()

# %%
# Exécute cette cellule quand tu auras terminé l'exercice
validation_exercice_classification()

# %% [markdown]
# !!! info Caractéristique d'un enregistrement cardiaque
# Pour diminuer notre erreur, notre algorithme doit maintenant utiliser l'enregistrement cardiaque au lieu de répondre au hasard.
# ![caracteristique.png](attachment:caracteristique.png)
# La caractéristique notée $x$ permet de résumer l'enregistrement en une seule information.
# !!!

# %% [markdown]
# !!! info Mesurer les baisses de fréquence cardiaque
# Nous avons vu que les cas ALARMANTS ont plus de baisses de fréquence cardiaque. Nous allons mesurer ça avec une caractéristique : le pourcentage des points avec une fréquence cardiaque inférieure à 100, c'est-à-dire
#
# $$ Caractéristique\ x = \frac{Nombre\ de\ secondes\ avec\ une\ fréquence\ cardiaque\ <\ 100}{temps\ total} $$
#
# La réponse sera donnée en pourcentage (en multipliant le résultat par $100\%$).
#
# **Exécute la cellule suivante** pour voir un exemple.
# !!!

# %%
affichage_10_frequences()

validation_execution_affichage_10_frequences()

# %% [markdown]
# !!! question 6) Quelle serait la caractéristique $x$ pour cette série de 10 valeurs ?
# Regarde le tableau et indique dans la cellule suivante la caractéristique que tu as calculée.
# !!!

# %%
x = ...

# NE PAS TOUCHER APRES CETTE LIGNE
validation_question_caracteristique()

# %% [markdown]
# ## D. Classificateur

# %% [markdown]
# !!! tip Utiliser la caractéristique pour classer les enregistrements cardiaques
# La caractéristique va nous permettre d'estimer si l'enregistrement cardiaque est un cas normal ou un cas alarmant.
# **Exécute la cellule suivante** pour afficher les enregistrements cardiaques et leur caractéristique
# !!!

# %%
affichage_banque(carac=1)
exercice_droite_carac()

validation_execution_affichage_classif()

# %% [markdown]
# !!! question 7) Placer les 10 premiers enregistrements cardiaques sur une droite
# Clique sur la droite pour placer les enregistrements cardiaques avec leur caractéristique en abscisse. Tu pourras exécuter la cellule suivante quand tu auras placé correctement les 10 premiers enregistrements cardiaques (dans l'ordre).
# !!!

# %%
validation_exercice_droite_carac()

# %% [markdown]
# !!! question 8) La caractéristique est-elle plus élevée pour les cas normaux ou pour les cas alarmants ?
# Regarde les points sur la droite et indique dans la cellule suivante quelle classe (Normal ou ALARMANT) a souvent une plus petite caractéristique que l'autre et inversement.
# !!!

# %%
r_petite_caracteristique = ...
r_grande_caracteristique = ...

# NE PAS TOUCHER APRES CETTE LIGNE
validation_question_ordre_caracteristique()

# %% [markdown]
# !!! question 9) Et maintenant, à partir de quelle valeur on décide que c'est un cas normal ?
# Regarde à nouveau la droite et choisis une valeur dite **seuil** $t$ pour séparer les cas normaux et les cas alarmants
# !!!

# %%
# Remplace les ... avec la valeur que tu as choisie
t = ...

# NE PAS TOUCHER APRES CETTE LIGNE
validation_question_seuil()

# %% [markdown]
# !!! info Résumé : la classification
# La classification est donc la dernière étape de l'algorithme. On répond Normal ou ALARMANT en fonction de la caractéristique $x$.
# ![classification.png](attachment:classification.png)
# **On compare $x$ à un seuil $t$** à définir : $\hat{r} = \left\{ \begin{array}{ll} Normal & \mbox{si $x \leq t$} \\ ALARMANT & \mbox{si $x > t$} \end{array} \right.$ (ou l'inverse selon les cas).
#
# Voici la fonction ci-dessous. **Exécute la cellule** pour passer à la suite
# !!!

# %%
# Fonction répondant au problème en fonction de la caractéristique x de la donnée que l'on doit classer
def classification(x, t):
    # Comparaison de la caractéristique au seuil t
    if x <= t:
        return Normal
    else:
        return ALARMANT
    
validation_execution_classif()

# %% [markdown]
# !!! abstract Notre algorithme est complet !
# En mettant bout à bout les étapes précédentes, nous pouvons construire un algorithme complet :
# ![full_algo.png](attachment:full_algo.png)
# Pour prédire si un enregistrement cardiaque est un cas normal ou un cas alarmant, l'algorithme calcule la caractéristique $x$ de l'enregistrement et compare cette caractéristique à un seuil $t$.
# Si la caractéristique est inférieure à $t$, l'algorithme prédit Normal, sinon il prédit ALARMANT.
# !!!
#
# !!! tip Teste cet algorithme
# **Exécute la cellule suivante** pour afficher l'interface de test de ton algorithme. Essaie de dessiner des images plus ou moins grosses pour voir comment elles sont classées.
# !!!

# %%
test_algorithme_ref()

validation_execution_test_algorithme_ref()

# %% [markdown]
# ## E. Calcul de l'erreur d'entraînement pour ce paramètre

# %% [markdown]
# !!! tip Exécute la cellule suivante
# Exécute la cellule suivante pour revoir les 10 premiers enregistrements cardiaques que tu as placés sur la droite.
# !!!

# %%
affichage_10_droite()

validation_execution_affichage_10_droite()

# %% [markdown]
# !!! question 10) Quel est ton pourcentage d'erreur sur les 10 premiers enregistrements cardiaques ?
# Avec le seuil que tu as choisi, combien d'erreurs l'algorithme a-t-il faites sur les 10 premiers enregistrements cardiaques ? (voir le graph ci-dessus). En déduire le pourcentage d'erreur à compléter dans la cellule suivante.
# !!!

# %%
erreur_10 = ...

# NE PAS TOUCHER APRES CETTE LIGNE
validation_question_score_seuil()

# %% [markdown]
# !!! tip Calcule ton erreur sur tout l'ensemble d'entraînement
# Exécute la cellule suivante pour calculer ton pourcentage d'erreur avec la caractéristique et le seuil que tu as choisi
# !!!

# %%
calculer_score_carac()

# %% [markdown]
# !!! abstract Améliorations
# Nous allons voir dans les prochaines étapes les différentes possibilités pour diminuer ton pourcentage d'erreur.
# !!!

# %% [markdown]
# ## F. Analyse statistique pour optimiser le seuil $t$

# %% [markdown]
# !!! info Histogramme et répartition des valeurs de la caractéristique
# Pour trouver le meilleur seuil $t$, on peut analyser les valeurs de la caractéristique $x$ pour les cas normaux et les cas alarmants.
# **Exécute la cellule suivante** pour visualiser la construction de cet histogramme.
# !!!

# %%
animation_histogramme()

validation_execution_animation_histogramme()

# %% [markdown]
# !!! tip Histogramme complet
# **Exécute la cellule suivante** pour afficher l'histogramme complet en grand.
# L'histogramme indique le nombre d'enregistrements cardiaques par classe pour chaque valeur de la caractéristique.
# !!!

# %%
afficher_histogramme()

validation_execution_afficher_histogramme()

# %% [markdown]
# !!! question 11) Quel histogramme correspond à quelle classe ?
# Regarde les deux histogrammes et indique dans la cellule suivante lequel correspond aux cas normaux et lequel correspond aux cas alarmants.
# !!!

# %%
r_histogramme_orange = ...
r_histogramme_bleu = ...

validation_question_hist_1()

# %% [markdown]
# !!! question 12) Lecture des histogrammes
# Combien y a-t-il de cas Normaux qui ont une caractéristique entre 8 et 10 ?
# Et pour les cas ALARMANTS ?
# !!!

# %%
# Remplace les ... par la valeur de ta réponse

nombre_Normal = ...

nombre_ALARMANT = ...

# NE PAS TOUCHER APRES CETTE LIGNE
validation_question_hist_2()

# %% [markdown]
# !!! question 13) Histogrammes et erreur
# Combien y a-t-il de cas Normaux dont la caractéristique est inférieure strictement à 6 ?
# Et pour les cas ALARMANTS ?
# !!!

# %%
# Remplace les ... par la valeur de ta réponse

nombre_Normal_inf_6 = ...

nombre_ALARMANT_inf_6 = ...


# NE PAS TOUCHER APRES CETTE LIGNE
validation_question_hist_3()

# %% [markdown]
# !!! abstract Choix du seuil avec les histogrammes
# Grâce à l'histogramme, on peut choisir un seuil $t$ qui sépare les valeurs de $x$ des cas normaux et des cas alarmants.
# **Exécute la cellule suivante** pour réafficher l'histogramme.
# !!!

# %%
afficher_histogramme(legend=True)

# %% [markdown]
# !!! question 14) Choisis un seuil $t$.
# Regarde l'histogramme et choisis le meilleur seuil $t$ pour classer les cas normaux et les cas alarmants.
# Remplace les `...` dans la cellule suivante avec ta réponse.
# !!!

# %%
t = ...

# NE PAS TOUCHER APRES CETTE LIGNE
validation_question_hist_seuil()

# %% [markdown]
# !!! tip Calcule ta nouvelle erreur
# **Exécute la cellule ci-dessous** pour calculer ton nouveau taux d'erreur, cette fois avec la valeur de $t$ optimale
# !!!

# %%
calculer_score_hist_seuil()

# %% [markdown]
# # Amélioration de la caractéristique : fais mieux !

# %% [markdown]
# !!! abstract Comment faire mieux ?
# En optimisant le seuil, tu as pu obtenir l'erreur la plus basse possible **en utilisant comme caractéristique celle que nous t'avons proposé.**
# Le seul moyen pour réduire encore le taux d'erreur est maintenant de trouver une meilleure caractéristique !
# !!!

# %% [markdown]
# ## G. Intervalle de fréquence cardiaque

# %% [markdown]
# !!! info Ajouter une autre valeur $v_{max}$
# En gardant la même stratégie, on peut changer la valeur $v_{min}$ minimum et ajouter une valeur $v_{max}$ maximum. La caractéristique est alors le pourcentage de valeurs au-dessus de $v_{max}$ ou en-dessous de $v_{min}$.
# !!!

# %% [markdown]
# !!! question 15) Choisis ton intervalle $[v_{min}, v_{max}]$
# **Exécute la cellule suivante** puis choisis les valeurs $v_{min}$ et $v_{max}$.
# !!!
# !!! info Conseil
# N'oublie pas que la caractéristique doit être la plus différente possible entre les cas Normaux et les cas ALARMANTS. Regarde les fréquences cardiaques qui sont atteintes presque uniquement par les cas ALARMANTS.
# !!!

# %%
afficher_customisation()

validation_execution_afficher_customisation()

# %% [markdown]
# !!! question 16) Choisis les paramètres de classification
# 1. À partir des histogrammes, indique dans la cellule suivante quelle classe (Normal ou ALARMANT) a souvent une plus petite caractéristique que l'autre et inversement.
# 2. À partir des histogrammes, choisis un seuil $t$ pour séparer les Normal et les ALARMANT. Essaie d'obtenir l'erreur la plus basse possible !
# !!!

# %%
r_petite_caracteristique = ...
r_grande_caracteristique = ...

t = ...

# NE PAS TOUCHER APRES CETTE LIGNE
calculer_score_custom()

# %% [markdown]
# !!! abstract Fin du Notebook
# Dans ce notebook, tu as :
#
# - exécuté des opérations numériques sur des enregistrements cardiaques
# - défini des caractéristiques pour passer de l'enregistrement cardiaque à un seul nombre
# - réalisé une classification par seuil pour utiliser cette caractéristique afin de répondre à la question
# - optimisé le seuil $t$ pour minimiser ton erreur avec chaque caractéristique testée
#
# S'il te reste du temps, tu peux continuer à tester des caractéristiques en répétant les étapes précédentes à partir de la définition de la fonction caractéristique
# !!!
#
# ## Bravo tu as découvert la classification avec une caractéristique.

# %% [markdown]
# ## H. Dans la suite nous te proposons d'essayer de coder des caractéristiques ou d'inventer la tienne. Cette fin est un bonus de niveau difficile voire très difficile.

# %% [markdown]
# !!! question 17) L'étendue comme caractéristique
# Complète directement la fonction `caracteristique` pour que l'étendue d'un enregistrement stocké dans d soit calculée. La fonction doit renvoyer une seule valeur.
# !!!

# %%
def caracteristique(d):
    
    # Exemple pour utiliser l'étendue comme caractéristique.
    # Complète le code en remplaçant les ... et en utilisant les fonctions min et max
    
    minimum = min(d)
    maximum = ...
    etendue = ...
    
    
    return etendue



# NE PAS TOUCHER APRES CETTE LIGNE
import utilitaires_common
utilitaires_common.challenge.remplacer_d_train_sans_nan()
validation_caracteristique_etendue_et_affichage()

# %% [markdown]
# !!! question 18) Choisis les paramètres de classification
# 1. À partir des histogrammes, indique dans la cellule suivante quelle classe (Normal ou ALARMANT) a souvent une plus petite caractéristique que l'autre et inversement.
# 2. À partir des histogrammes, choisis un seuil $t$ pour séparer les cas normaux et les cas alarmants. Essaie d'obtenir l'erreur la plus basse possible !
# !!!

# %%
r_petite_caracteristique = ...
r_grande_caracteristique = ...

t = ...

# NE PAS TOUCHER APRES CETTE LIGNE
calculer_score_code_etendue()

# %% [markdown]
# ## I. Proposition libre
# !!! question 19) Invente ta propre caractéristique
# Complète directement la fonction `caracteristique` dans la cellule suivante avec ton idée. La fonction doit renvoyer une seule valeur.
# La suite peut être difficile si tu n'as pas de connaissance en Python. Bravo d'être arrivé jusque là !
# !!!
# !!! tip Exemple
# Tu peux essayer de coder une fonction  qui renvoie :
# -la moyenne des valeurs de l'enregistrement d.
# - ou l'écart type de la série des valeurs de l'enregistrement.
# - ou la somme des valeurs de l'enregistrement.
# !!!

# %%
def caracteristique(d):
    # Ajouter ton code ici
    
    
    
    return ...


# NE PAS TOUCHER APRES CETTE LIGNE
validation_caracteristique_libre_et_affichage()

# %% [markdown]
# !!! question 20) Choisissez les paramètres de classification
# 1. À partir des histogrammes, indique dans la cellule suivante quelle classe (Normal ou ALARMANT) a souvent une plus petite caractéristique que l'autre et inversement.
# 2. À partir des histogrammes, choisis un seuil $t$ pour séparer les cas normaux et les cas alarmants. Essaie d'obtenir l'erreur la plus basse possible !
# !!!

# %%
r_petite_caracteristique = ...
r_grande_caracteristique = ...

t = ...

# NE PAS TOUCHER APRES CETTE LIGNE
calculer_score_code_free()
