# %% [markdown]
# # MathAData - Statistics - 1

# %% [markdown]
# ## Image classification of 2s and 7s

# %% [markdown]
# !!! abstract Goal of the Lab
# In this Notebook, we will build an algorithm that predicts whether a 2 or a 7 is written on an image.
# ![2_7.png](attachment:2_7.png)
# !!!

# %% [markdown]
# !!! tip Execute a cell
# To start, click on the code cell below then press the <span style="display: inline-block; margin: auto 1rem; vertical-align: middle">![executer.png](attachment:executer.png)</span> button or the keyboard keys <span style="display: inline-block; margin: auto 1rem; vertical-align: middle">![shift.png](attachment:shift.png)</span>+<span style="display: inline-block; margin: auto 1rem; vertical-align: middle">![enter.png](attachment:enter.png)</span>
# When the code has been executed, a number will appear between the brackets on the left: <span style="display: inline-block; margin: auto 1rem; vertical-align: middle">![cellule_executee.png](attachment:cellule_executee.png)</span>
# !!!

# %%
from utilitaires_histogramme import *
from utilitaires_mnist import *

# %% [markdown]
# !!! tip Database
# Run the following cell to display the data.
# !!!

# %%
display_bank()

validation_execution()

# %% [markdown]
# !!! question How many real images of 7 are present among the first 10 images?
# **Replace the `...`** in the following cell with your answer **then execute it**.
# !!!

# %%
Count_7 = ...

# DO NOT TOUCH THIS LINE
validation_execution_nombre_7()

# %% [markdown]
# !!! question How many images does the database contain?
# **Replace the `...`** in the following cell with your answer **then execute it**.
# !!!

# %%
Count_total = ...

# DO NOT TOUCH THIS LINE
validation_execution_nombre_total()

# %% [markdown]
# ## Starting Point

# %% [markdown]
# !!! tip How an algorithm works
# An algorithm receives a data, performs operations, and gives an answer.
# ![algo_blackbox_mnist.png](attachment:algo_blackbox_mnist.png)
# !!!
# !!! abstract Lazy algorithm: Always returns 2.
# LucIA doesn't want to tire herself out and proposes a very simple algorithm **that always returns 2**.
# !!!

# %%
import utilitaires_common

def algorithm(d):
    return 2

validation_execution_algo_fixe()

# %% [markdown]
# !!! question What does the lazy algorithm answer for these three images?
# ![frise_trois_images.png](attachment:frise_trois_images.png)
# **Replace the `...`** in the following cell with your answer **then execute it**.
# !!!

# %%
Answer_Image_A = ...
Answer_Image_B = ...
Answer_Image_C = ...

# DO NOT TOUCH THIS LINE
validation_question_faineant()

# %% [markdown]
# !!! info The percentage error: a way to evaluate your algorithm
# The lower the percentage error, the better is your solution.
#
# $$\text{percentage error} = \frac{\text{Number of misclassified images}} {\text{Total number of images}} \times 100$$
# A misclassified image is one for which the algorithm gave a prediction different from the true class of the image:
# $$\hat r \neq r$$
# !!!

# %%
display_bank(showPredictions=True)

validation_execution_calcul_score()

# %% [markdown]
# !!! question What is the algorithm's percentage error of the first 10 images?
# Calculate the percentage error of the algorithm. **Replace the `...`** in the following cell with your answer (only the number without the %) **then execute it**.
# !!!

# %%
error_10 = ...

# DO NOT TOUCH THIS LINE
validation_question_score_fixe()

# %% [markdown]
# !!! tip Error on all the images
# Run the following cell to compute the percentage error on all data.
# !!!

# %%
compute_score_step_1()

# %% [markdown]
# ## Numerical Image

# %% [markdown]
# !!! abstract What is an image?
# To lower our error, our algorithm must "look at" the image. We need to understand what an image is for the computer.
# !!!
# !!! tip Calculations on the image
# For the computer, an image is an array of numbers. Each number corresponds to a pixel of the image. Each pixel has a value between 0 and 255, 0 for black and 255 for white.
# ![pixels.png](attachment:pixels.png)
# Run the following cell to display the image.
# !!!

# %%
display_image(d)
display_table(d)

validation_execution_affichage()

# %% [markdown]
# !!! question What is the value of pixel (18,15)?
# Read the value of the pixel at position (18,15) in the table and fill in its value **in place of the `...`** in the cell below **then execute it**.
# Note: The first coordinate is the row number, the second is the column number: (row, column).
# !!!

# %%
pixel = ...

# DO NOT TOUCH THIS LINE
validation_question_pixel()

# %% [markdown]
# !!! question Turn pixel (17,15) into a black pixel
# **Replace the `...` below** with the new value to give to the pixel so that it is black **then execute it**.
# !!!

# %%
d[17,15] = ...

# DO NOT TOUCH THESE LINES
validation_question_pixel_noir()
display_image(d,(17,15))
display_table(d,(17,15))

# %% [markdown]
# ## Feature computation

# %% [markdown]
# !!! info Feature of an image
# To lower our percentage error, our algorithm must now use the image instead of guessing.
# ![caracteristique_mnist.png](attachment:caracteristique_mnist.png)
# The feature denoted $x$ allows us to summarize the image into a single piece of information.
# !!!

# %% [markdown]
# !!! tip The mean
# To summarize the values of certain pixels into a single value, we compute the mean of these pixels.
# !!!

# %% [markdown]
# ![image_7_carre_marge.png](attachment:image_7_carre_marge.png)
# ![tableau_7_carre.png](attachment:tableau_7_carre.png)
# !!! question Calculate the mean over the red pixels
# Calculate the mean of the pixels in the area highlighted in red. Provide your answer **in place of the `...`** in the cell below **then execute it**.
# !!!

# %%
mean_zone_4pixels = ...

# DO NOT TOUCH THIS LINE
validation_question_moyenne()

# %% [markdown]
# !!! tip Feature: mean of the entire image
# We will take as a feature the mean of the image, i.e. the mean of the values of **all** its pixels.
# !!!

# %% [markdown]
# ## Classifier

# %% [markdown]
# !!! info Classification
# Classification is the last step of the algorithm. We answer 2 or 7 based on the feature $x$.
# ![classification_mnist.png](attachment:classification_mnist.png)
# **We compare $x$ to a threshold $t$** to be defined: $\hat{r} = \left\{ \begin{array}{ll} 2 & \mbox{if $x \leq t$} \\ 7 & \mbox{if $x > t$} \end{array} \right.$ or the inverse: $\hat{r} = \left\{ \begin{array}{ll} 7 & \mbox{if $x \leq t$} \\ 2 & \mbox{if $x > t$} \end{array} \right.$
# !!!

# %%
display_bank(carac=1)
exercise_feature_line()

validation_execution_affichage_classif()

# %% [markdown]
# !!! question Place the first 10 images on the axis
# Click on the line to place the images with their feature on the x-axis. You can execute the next cell when you have correctly placed the first 10 images (in order).
# !!!

# %%
validation_exercice_droite_carac()

# %% [markdown]
# !!! question Is the feature higher for 2 or for 7?
# Look at the points on the line and indicate in the following cell which class (2 or 7) often has a smaller feature than the other and vice versa.
# !!!

# %%
r_low_feature = ...
r_high_feature = ...

# DO NOT TOUCH THIS LINE
validation_question_ordre_caracteristique()

# %% [markdown]
# !!! question Choose a threshold $t$.
# Look again at the line and choose a threshold $t$ to separate 2 and 7.
# !!!

# %%
# Replace the ... with the value you've chosen
t = ...

# DO NOT TOUCH THIS LINE
validation_question_seuil()

# %% [markdown]
# !!! tip Final function
# From your two previous answers, we can code the `classification` function:
# !!!

# %%
# Function responding to the problem based on the characteristic x of the image to be classified
def classification(x, t):
    # Comparison of the characteristic with threshold t
    if x <= t:
        return r_low_feature
    else:
        return r_high_feature

validation_execution_classif()

# %% [markdown]
# !!! abstract Our algorithm is complete!
# With the previous steps, we can build a complete algorithm:
# ![full_algo_mnist.png](attachment:full_algo_mnist.png)
# Indeed, we are able to calculate a feature from the image, then decide if the image represents a 2 or a 7 by looking at this feature.
# !!!

# %% [markdown]
# ## Training error computation for this parameter

# %% [markdown]
# !!! tip Run the following cell
# Run the following cell to display again the images with their feature.
# !!!

# %%
display_bank(carac=1)

validation_execution_affichage_score()

# %% [markdown]
# !!! question What is your percentage error of the first 10 images?
# With the threshold you have chosen, how many errors did the algorithm make on the first 10 images? (See table above). Deduce the percentage error to fill in the following cell.
# !!!

# %%
error_10 = ...

# DO NOT TOUCH THIS LINE
validation_question_score_seuil()

# %% [markdown]
# !!! tip Calculate your error with the entire training set
# Run the following cell to calculate your error with the entire training set.
# !!!

# %%
compute_score_feature()

# %% [markdown]
# !!! abstract Improvements
# In the next steps, we will explore different ways to lower your percentage error.
# !!!

# %% [markdown]
# ## Statististical analysis to optimize threshold $t$

# %% [markdown]
# !!! info Histogram and distribution of feature values
# To find the best threshold $t$, we can analyze the values of the feature $x$ for 2 and 7.
# **Run the following cell** to visualize the construction of this histogram.
# !!!

# %%
animation_histogramme()

validation_execution_animation_histogramme()

# %% [markdown]
# !!! tip Complete histogram
# **Run the following cell** to redisplay the complete histogram in large.
# The histogram indicates the number of images per class for each value of the feature.
# !!!

# %%
display_histogram()

validation_execution_afficher_histogramme()

# %% [markdown]
# !!! question Which histogram corresponds to which digit?
# Look at the two histograms and indicate in the following cell which one corresponds to 2 and which one corresponds to 7.
# !!!

# %%
r_orange_histogram = ...
r_blue_histogram = ...

validation_question_hist_1()

# %% [markdown]
# !!! question Reading the histograms
# How many images of 2 are there that have a feature between 20 and 22?
# And for images of 7?
# !!!

# %%
# Remplace ... by your answer

count_2 = ...

count_7 = ...

validation_question_hist_2()

# %% [markdown]
# !!! question Histograms and error
# How many images of 2 are there whose feature is less than 16?
# And for images of 7?
# !!!

# %%
# Remplace ... by your answer

count_2_less_than_16 = ...

count_7_less_than_16 = ...

validation_question_hist_3()

# %% [markdown]
# !!! abstract Threshold choice with histograms
# Using the histogram, we can choose a threshold $t$ that separates the values of $x$ of 2 and 7.
# **Run the following cell** to redisplay the histogram.
# !!!

# %%
display_histogram(legend=True)

# %% [markdown]
# !!! question Choose a threshold $t$.
# Look at the histogram and choose the best threshold $t$ to classify 2 and 7.
# Replace the `...` in the following cell with your answer.
# !!!

# %%
t = ...

# DO NOT TOUCH THIS LINE
validation_question_hist_seuil()

# %% [markdown]
# !!! tip Calculate your new error
# **Run the cell below** to calculate your new percentage error, this time with the optimal value of $t$
# !!!

# %%
compute_score_hist_thresold()

# %% [markdown]
# ## Improve your feature !

# %% [markdown]
# !!! abstract How to do better?
# By optimizing the threshold, you were able to get the lowest possible percentage error **using as feature the mean of all the pixels of the image.**
# The only way to further reduce the percentage error now is to find a better feature!
# !!!

# %% [markdown]
# ##  Mean over an area of the image

# %% [markdown]
# !!! info Use the mean more intelligently
# A first approach to improve your feature: use the mean only on an area of the image that seems interesting to you to distinguish between 2s and 7s.
# !!!

# %% [markdown]
# !!! question Choose the area of the image on which you will calculate the mean
# Run the following cell to select the area.
# !!!
# !!! info Advice
# Remember that the feature must be as different as possible depending on whether the image is a 2 or a 7. Look at the images to find an area that differs the most between the two digits.
# !!!

# %%
display_customization()

validation_execution_afficher_customisation()

# %% [markdown]
# !!! question Choose classification parameters
# 1. From the histograms, indicate in the following cell which class (2 or 7) often has a smaller feature than the other and vice versa.
# 2. From the histograms, choose a threshold $t$ to separate 2 and 7. Try to get the lowest possible error!
# !!!

# %%
r_low_feature = ...
r_high_feature = ...

t = ...

# DO NOT TOUCH THIS LINE
compute_custom_score()

# %% [markdown]
# ## Free Play

# %% [markdown]
# !!! question Invent your own feature
# Directly complete the `feature` function in the following cell with your idea. The function must return a single value.
# !!!
# !!! tip Example
# It might be a good idea to continue using means with the `area_mean` function. You can combine several by adding them, multiplying, adding coefficients...
# We have pre-filled the function to give an example.
# !!!

# %%
def feature(d):
    # Modify feature computation with your ideas
    # Use area_mean(d, (..., ...), (..., ...)) and operations +,-,*
    
    a = 1
    b = -1

    x = a * area_mean(d, (0,0), (14,27)) + b * area_mean(d, (14,0), (27,27))
    return x

display_histogram(feature=feature)

# %% [markdown]
# !!! question Choose classification parameters
# 1. From the histograms, indicate in the following cell which class (2 or 7) often has a smaller feature than the other and vice versa.
# 2. From the histograms, choose a threshold $t$ to separate 2 and 7. Try to get the lowest possible error!
# !!!

# %%
r_low_feature = ...
r_high_feature = ...

t = ...

# DO NOT TOUCH THIS LINE
compute_score_code()

# %% [markdown]
# !!! abstract End of Notebook
# In this notebook, you have:
#
# - Performed numerical operations on images represented by an array of numbers
# - Defined features to move from the image to a single number
# - Used threshold classification to use this feature to answer the question
# - Optimized the threshold $t$ to minimize your error with each tested feature
# If you have time left, you can continue testing features by repeating the previous steps starting from the definition of the `feature` function.
# !!!
